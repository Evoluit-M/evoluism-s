# %% [markdown]
# # CCM Calculator demo notebook
#
# This notebook reproduces the core CCM calculation:
#
# $$ \text{multiplier} = \exp(\beta \cdot \Delta C). $$

# %%
from math import exp
from app.ccm_calculator import innovation_multiplier

beta = 0.69
delta_c = 1.2
multiplier = innovation_multiplier(beta, delta_c)
multiplier

# %%
deltas = [0.0, 0.4, 0.8, 1.0, 1.2]
rows = []
for d in deltas:
    rows.append((d, innovation_multiplier(beta, d)))
rows
